# %%
['rahul', 'vidhatri', 'sanika', 'vidhatri']
[10, 20, 30, 30]
# Out:
# ['rahul', 'vidhatri', 'sanika', 'vidhatri']
# [10, 20, 30, 30]

# %%
{'rahul', 'vidhatri', 'sanika', 'vidhatri'}
{10, 20, 30, 30, 30, 30}
# Out:
# {'rahul', 'sanika', 'vidhatri'}
# {10, 20, 30}

# %%
names = ['rahul', 'vidhatri', 'sanika', 'vidhatri']
names[0]
names[1]
names[2]
names[3]
# Out:
# 'rahul'
# 'vidhatri'
# 'sanika'
# 'vidhatri'

# %%
names = {'rahul', 'vidhatri', 'sanika', 'vidhatri'}
# names[0] not possible
names
# Out:
# {'rahul', 'sanika', 'vidhatri'}

# %%
names = ['rahul', 'vidhatri', 'sanika', 'vidhatri']
names.append('cmd')

names
# Out:
# ['rahul', 'vidhatri', 'sanika', 'vidhatri', 'cmd']

# %%
names = ('rahul', 'vidhatri', 'sanika', 'vidhatri')
# names.append('cmd')
names
# Out:
# ('rahul', 'vidhatri', 'sanika', 'vidhatri')

# %% [markdown]
# to make a collection of values, you've 3 options
#
# 1. make a list (default choice)
# 2. make a set (use this if you don't want duplicates in collection, caution: no order/index)
# 3. make a tuple (use this if you don't want to modify the collection)

# %%
# list methods

L = [5, 8, 1, 3, 10, 5]

print(f'{L.index(5)=}')
print(f'{L.count(5)=}')

L.append(99)
L.remove(5)

L.sort()
print(f'{L=}')

L.reverse()
print(f'{L=}')
# Out:
# L.index(5)=0
# L.count(5)=2
# L=[1, 3, 5, 8, 10, 99]
# L=[99, 10, 8, 5, 3, 1]

# %%
my_set = {5, 8, 1, 3, 10, 5}

my_set.add(99)
my_set.remove(8)  # remove value, but error if value not present
my_set.discard(18)  # remove only if value if present, otherwise pass, no error

print(f'{my_set=}')
# Out:
# my_set={1, 3, 99, 5, 10}

# %%
set_1 = {1, 2, 3, 4, 5, 6}
set_2 = {5, 6, 10}

set_1 | set_2  # union (or) [pipe]
set_1 & set_2  # intersection (and) [ampersand]
set_1 - set_2  # difference [hyphen]
set_1 ^ set_2  # symmetric difference (union - intersection) [caret]
# Out:
# {1, 2, 3, 4, 5, 6, 10}
# {5, 6}
# {1, 2, 3, 4}
# {1, 2, 3, 4, 10}

# %%
set_1 = {1, 2, 3, 4, 5, 6}
set_2 = {5, 6, 10}

set_1.union(set_2)  # union (or) [pipe]
set_1.intersection(set_2)  # intersection (and) [ampersand]
set_1.difference(set_2)  # difference [hyphen]

# symmetric difference (union - intersection) [caret]
set_1.symmetric_difference(set_2)
# Out:
# {1, 2, 3, 4, 5, 6, 10}
# {5, 6}
# {1, 2, 3, 4}
# {1, 2, 3, 4, 10}

# %%
tuple_1 = (10, 20, 30, 30, 30, 30)

tuple_1.index(10)
tuple_1.count(30)
# Out:
# 0
# 4

# %%
L = [10, 20, 30, 30, 50, 10, 20, 40]

# duplicates must go away
# collection should not be modified later (immutability: the state of not changing)

tuple(set(L))
# Out:
# (40, 10, 50, 20, 30)

# %%
data = ('Vidhatri', 12, 50)

name, grade, weight = data # tuple unpacking (no. of vars on LHS must equal len of tuple)

print(name, grade, weight)
# Out:
# Vidhatri 12 50

# %%
data = {
    'name': 'vidhatri',  # key-value pair
    'age': 20,
    'best_friend': {
        'name': 'someone',
        'age': 19,
        'father': {
            'job': 'businessman',
            'salary': '10lacs'
        }
    },
    'fav_movies': ['abc', 'xyz', 'qwe', 'qwe', 'qwe', 'qwe'],
}

# data['best_friend']['father']['salary']
data['fav_movies']
# Out:
# ['abc', 'xyz', 'qwe', 'qwe', 'qwe', 'qwe']

# %%
employee = {
    'name': 'john',
    'job': 'software developer',
    'department': 'backend',
    'age': 25,
    'salary': '15 lacs'
}

# employee.keys()  # keys of dict
# employee.values()  # all the values in dict
# employee.items()  # all key-value pairs/tuple

# for key in employee.keys():
#   print(f'key is {key}')

# for value in employee.values():
#   print(f'value is {value}')

# for key, value in employee.items():
#   print(f'key is {key}, value is {value}')

# dict_items [but we were hoping it to be of type `list`, WTH!!]
# dict_items: can't enjoy indexing or any list features 😢
# dict_items: but you still can loop over it [for key, value in dict.items()] 😃
# type(employee.items())

# converted to a list to enjoy indexing and other list benefits
# key, value = list(employee.items())[0]
# print(key, value)

# for key, value in employee.items():
#   print(key, value)

# print(type(employee.keys()))  # 🚨 not a `list`
# print(type(employee.values()))  # 🚨 not a `list`
# print(type(employee.items()))  # 🚨 not a `list`

# %%
employee = {
    'name': 'john',
    'job': 'software developer',
    'department': 'backend',
    'age': 25,
    'salary': '15 lacs'
}

# key in employee <- this checks if key present in dict (T/F)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
words = ['a', 'b', 'c', 'a', 'd', 'a', 'b', 'c', 'e',
         'd', 'a', 'q', 't', 'v', 'z', 'x', 's', 'a', 'b', 'd', 's', 'e',
         'f', 'g', 'a', 'b', 'c', 'e', 't', 'q']

words = ['public', 'uber', 'private', 'uber',
         'public', 'uber', 'private', 'uber']

freq = {}

for word in words:
  if word not in freq:
    freq[word] = 0

  freq[word] += 1

freq
# Out:
# {'public': 2, 'uber': 4, 'private': 2}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
number = '019214'

digit_to_word = {  # <- this is a map of numeric digits to their english word
    '1': 'one',
    '2': 'two',
    '3': 'three',
    '4': 'four',
    '5': 'five',
    '6': 'six',
    '7': 'seven',
    '8': 'eight',
    '9': 'nine',
    '0': 'zero',
}

for digit in number:
  print(digit_to_word[digit])
# Out:
# zero
# one
# nine
# two
# one
# four

# %% [markdown]
# Table/Map [this concept is implemented in python as dict]
#
# 1: one
# 2: two
# 3: three
# .
# .
# .
# numeric digit: english word for that digit

# %%
digit_to_word = {
    1: 'one',
    2: 'two',
    3: 'three',
    4: 'four',
    5: 'five',
    6: 'six',
    7: 'seven',
    8: 'eight',
    9: 'nine',
    0: 'zero',
}

digit_to_word[2]
# Out:
# 'two'

# %%
dict_1 = {'good': 4, 'day': 3}


def is_key(D, key):
  return key in D


def value(D, key):
  if not is_key(D, key):
    return None

  return D[key]


# is_key(D=dict_1, key='good')
# is_key(D=dict_1, key='bad')

print(value(dict_1, 'bad'))
# Out:
# None

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
marks = {
    'rahul': 90,
    'vidhatri': 95,
    'sanika': 90,
    'cmd': 80,
}

# 90 -> ['rahul', 'sanika']


def value_to_keys(D, value):
  keys_to_return = []

  for key in D.keys():
    if D[key] == value:
      keys_to_return.append(key)

  return keys_to_return


value_to_keys(marks, 90)  # ['rahul', 'sanika']
# Out:
# ['rahul', 'sanika']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
marks = {
    'rahul': 90,
    'vidhatri': 95,
    'sanika': 90,
    'cmd': 80,
}


def dict_to_list(D):
  return list(D.items())


dict_to_list(marks)
# Out:
# [('rahul', 90), ('vidhatri', 95), ('sanika', 90), ('cmd', 80)]

# %%
marks_list = [('rahul', 90), ('vidhatri', 95), ('sanika', 90), ('cmd', 80)]


def list_to_dict(L):
  new_dict = {}

  for key, value in L:
    new_dict[key] = value

  return new_dict


list_to_dict(marks_list)
# Out:
# {'rahul': 90, 'vidhatri': 95, 'sanika': 90, 'cmd': 80}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
student_entry = {
    'SeqNo': 1, 'Name': 'Devika', 'Gender': 'F', 'City': 'Bengaluru', 'Mathematics': 85, 'Physics': 100,
    'Chemistry': 79, 'Biology': 75, 'Computer Science': 88, 'History': 60, 'Civics': 88, 'Philosophy': 95
}

(student_entry['Name'], student_entry['Mathematics'])
# Out:
# ('Devika', 85)

# %%
dataset = [
    {
        'SeqNo': 1, 'Name': 'Devika', 'Gender': 'F', 'City': 'Bengaluru', 'Mathematics': 85, 'Physics': 100,
        'Chemistry': 79, 'Biology': 75, 'Computer Science': 88, 'History': 60, 'Civics': 88, 'Philosophy': 95
    },

    {
        'SeqNo': 2, 'Name': 'Rahul', 'Gender': 'F', 'City': 'Bengaluru', 'Mathematics': 90, 'Physics': 100,
        'Chemistry': 79, 'Biology': 75, 'Computer Science': 88, 'History': 60, 'Civics': 88, 'Philosophy': 95
    },

    {
        'SeqNo': 3, 'Name': 'Vidhatri', 'Gender': 'F', 'City': 'Bengaluru', 'Mathematics': 70, 'Physics': 100,
        'Chemistry': 79, 'Biology': 75, 'Computer Science': 88, 'History': 60, 'Civics': 88, 'Philosophy': 95
    }
]

marks_scored = []
for entry in dataset:
  pair = (entry['Name'], entry['Mathematics'])
  marks_scored.append(pair)

print(f'{marks_scored=}')
# Out:
# marks_scored=[('Devika', 85), ('Rahul', 90), ('Vidhatri', 70)]

# %%
def get_marks(dataset, subject):
  marks = []
  for entry in dataset:
    pair = (entry['Name'], entry[subject])
    marks.append(pair)

  return marks


get_marks(dataset, 'Mathematics')
# Out:
# [('Devika', 85), ('Rahul', 90), ('Vidhatri', 70)]

# %% [markdown]
# 1. processor
#    1. intel
#       1. i3, i5, i7, i9 (i version)
#       2. gen 8, 9, 10, 11, 12, 13 (generation)
#    2. amd
#       1. ryzen 3, 5, 7 (ryzen version)
#       2. 3000, 5000, 7000 (series)
#
# 2. processor category
#   1. U series: day-to-day performance, lightweight laptop/notebook, power-saving
#   2. H series: high performance, gaming/graphics laptops, power-consuming
#
# 3. usage
#    1. ryzen 3 3000u, i3 11gen -> basic day to day task ✅
#    2. ryzen 5 5000u, i5 11gen -> basic day to day task + super smooth experience ✅
#    3. ryzen 5 5000h, i5 12gen, i7 11gen -> gaming/graphics performance (if GPU is available) 🔥
#
# 4. RAM 8GB ✅ (but 16GB 🔥)
# 5. Integrated GPU (this comes built-in with CPU ✌️)
# 6. Dedicated GPU (external, depends on whether you need it)
#    1. basic day to day task ❌
#    2. gaming/graphics performance ✅
#    3. hardcore ml: nvidia, normal ml: amd
# 7. SSD 512 GB ✅

# %% [markdown]
# 1. thin & slim laptops
#    1. 14 inch
#    2. lightweight
#    3. portability ✌️✅
#    4. dedicated GPU (bcz of high power need) ❌
#    5. cheap
#    6. Ryzen 3 Quad Core 5300U
# 2. gaming laptops
#    1. 15.6 inch
#    2. bulky/heavy
#    3. portability 😞❌
#    4. dedicated GPU ✅
#    5. costly
#    6. Ryzen 5 Hexa Core AMD R5-5600H

# %% [markdown]
# 1. Quad Core: 4 cores/8 threads
# 2. Hexa Core: 6 cores/12 threads
#
# 👉 Threads are needed for multitasking.

# %% [markdown]
# 3.3 GHz 🚀
# 2.6 GHz 🐌

# %% [markdown]
# 1. Single-Core Performance
#    1. single app run
# 2. Multi-Core Performance
#    1. many apps running at same time
#    2. video editing
#    3. ml
#    4. vs code
#    5. chrome

# %% [markdown]
# 1. NVIDIA GeForce GTX 1650 🚀
# 2. NVIDIA GeForce RTX 2050 🚀🚀
# 3. NVIDIA GeForce RTX 3050 🚀🚀🚀

# %% [markdown]
# Performance-cores -> multi threaded (2 threads per core)
# Efficient-cores -> single threaded (1 thread per core)

# %% [markdown]
# Normal freq: 3.3Ghz (normal operations)
# Turbo freq: 4.4Ghz (boosted operations, power consuming, heat generate)
